# %% [markdown]
# # TTK Pipeline

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns
import csd_functions
import sys
# from paraview.simple import *
sns.set()

# %% [markdown]
# Plot from generic hnn data dir

# %%
# %matplotlib inline

# HNN_dir = 'C:/Users/Nick/hnn/data/default'
HNN_dir = 'C:/Users/Nick/hnn/data/test_sweep-t_evprox_1_2_t_evdist_1_1'


plt.figure(figsize=(8,8))
Z_hnn = csd_functions.csd_interp(HNN_dir,10)

plt.subplot(121)
plt.imshow(Z_hnn, interpolation='none', aspect='auto', origin='upper', cmap='jet_r',
                  norm=colors.SymLogNorm(linthresh=0.20, linscale=0.001,
                                      vmin=Z_hnn.min(), vmax=-Z_hnn.min()))
plt.title('Tresholded')


plt.subplot(122)
plt.imshow(Z_hnn, interpolation='none', aspect='auto', origin='upper', cmap='jet_r',vmin=Z_hnn.min(), vmax=-Z_hnn.min())

plt.colorbar()
plt.title('No threshold')
plt.show()

# %% [markdown]
# Load data from parameter sweep

# %%
with open('test_sweep_names.csv', newline='') as f:
    reader = csv.reader(f)
    f_names = list(reader)
f_names = f_names[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-39dd2434e18b> in <module>
# ----> 1 with open('test_sweep_names.csv', newline='') as f:
#       2     reader = csv.reader(f)
#       3     f_names = list(reader)
#       4 f_names = f_names[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_sweep_names.csv'
